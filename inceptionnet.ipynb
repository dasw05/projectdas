# %% [markdown]
# <a href="https://colab.research.google.com/github/dasw05/projectdas/blob/main/inceptionnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/MHersche/eegnet-based-embedded-bci.git
# Out:
# Cloning into 'eegnet-based-embedded-bci'...
# remote: Enumerating objects: 36846, done.
# remote: Counting objects: 100% (36846/36846), done.
# remote: Compressing objects: 100% (30625/30625), done.
# remote: Total 36846 (delta 6205), reused 36846 (delta 6205), pack-reused 0
# Receiving objects: 100% (36846/36846), 33.09 MiB | 7.98 MiB/s, done.
# Resolving deltas: 100% (6205/6205), done.

# %%
# !wget -r -N -c -np https://physionet.org/files/eegmmidb/1.0.0/
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: 2064384 (2.0M) [application/octet-stream]
# Saving to: ‘physionet.org/files/eegmmidb/1.0.0/S092/S092R03.edf’
#
# physionet.org/files 100%[===================>]   1.97M  --.-KB/s    in 0.03s
#
# 2022-06-13 01:40:08 (68.4 MB/s) - ‘physionet.org/files/eegmmidb/1.0.0/S092/S092R03.edf’ saved [2064384/2064384]
#
# --2022-06-13 01:40:08--  https://physionet.org/files/eegmmidb/1.0.0/S092/S092R03.edf.event
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 566 [text/plain]
# Saving to: ‘physionet.org/files/eegmmidb/1.0.0/S092/S092R03.edf.event’
#
# physionet.org/files 100%[===================>]     566  --.-KB/s    in 0s
#
# 2022-06-13 01:40:08 (205 MB/s) - ‘physionet.org/files/eegmmidb/1.0.0/S092/S092R03.edf.event’ saved [566/566]
#
# --2022-06-13 01:40:08--  https://physionet.org/files/eegmmidb/1.0.0/S092/S092R04.edf
# Reusing existing connection to physionet.org:443.
# ...

# %%
# !python /content/eegnet-based-embedded-bci/main_global.py
# Out:
# Data from runs: [1, 4, 6, 8, 10, 12, 14]
# tcmalloc: large alloc 1078640640 bytes == 0x483a8000 @  0x7f4f3e5301e7 0x7f4f3be810ce 0x7f4f3bed7cf5 0x7f4f3bf8086d 0x7f4f3bf8117f 0x7f4f3bf812d0 0x4bc4ab 0x7f4f3bec2944 0x59371f 0x515244 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x549e0e 0x593fce 0x548ae9 0x5127f1 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7f4f3e12dc87 0x5b621a
# tcmalloc: large alloc 1211105280 bytes == 0x50d3c000 @  0x7f4f3e5301e7 0x7f4f3be810ce 0x7f4f3bed7cf5 0x7f4f3bf8086d 0x7f4f3bf8117f 0x7f4f3bf812d0 0x4bc4ab 0x7f4f3bec2944 0x59371f 0x515244 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x549e0e 0x593fce 0x548ae9 0x5127f1 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7f4f3e12dc87 0x5b621a
# ...

# %%
# !pip install pyedflib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.4 MB 15.3 MB/s
# ...

# %%
# !python /content/eegnet-based-embedded-bci/main_ss.py
# Out:
# Data from runs: [1, 4, 6, 8, 10, 12, 14]
# 2022-06-13 03:25:35.093206: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# S1	1.0000	0.5833
# Data from runs: [1, 4, 6, 8, 10, 12, 14]
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# S2	1.0000	0.6190
# Data from runs: [1, 4, 6, 8, 10, 12, 14]
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# S3	1.0000	0.5714
# ...
